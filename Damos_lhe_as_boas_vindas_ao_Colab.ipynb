# %% [markdown]
# <a href="https://colab.research.google.com/github/TETEUSA007/1CCPQ-Python-FIAP-2026/blob/main/Damos_lhe_as_boas_vindas_ao_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biblioteca para manipulação de tabelas
import pandas as pd

# %%
# Criando um Data Frame
dados = pd.read_csv('/content/DATA_SAMPLE_ORANGE.csv')

# %% [markdown]
# # **Análise Exploratória**

# %% [markdown]
# **# Visualização dos primeiros registros**

# %%
dados.head()
# Out:
#                   Date                 Time  Global_active_power  \
# 0  2008-01-12 00:00:00  2026-04-24 09:44:00                1.502
# 1  2006-12-17 00:00:00  2026-04-24 23:39:00                0.374
# 2  2009-03-06 00:00:00  2026-04-24 17:01:00                0.620
# 3  2007-09-05 00:00:00  2026-04-24 05:53:00                0.280
# 4  2008-12-14 00:00:00  2026-04-24 02:57:00                1.372
#
#    Global_reactive_power  Voltage  Global_intensity  Sub_metering_1  \
# 0                  0.074   240.17               6.4               0
# 1                  0.264   245.50               1.8               0
# 2                  0.300   239.85               3.0               0
# 3                  0.200   235.72               1.4               0
# 4                  0.054   243.95               5.6               0
#
#    Sub_metering_2  Sub_metering_3
# 0               0              18
# 1               2               0
# 2               1               1
# ...

# %% [markdown]
# # Dimensões do data frame

# %%
dados.shape
(102464, 9)
# Out:
# (102464, 9)

# %%
print(f'A tabela possui {dados.shape[0]} registros (linhas) e {dados.shape[1]} atributos (colunas)')
# Out:
# A tabela possui 102464 registros (linhas) e 9 atributos (colunas)

# %% [markdown]
# # Informações básicas sobre os registros

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102464 entries, 0 to 102463
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Date                   102464 non-null  object
#  1   Time                   102464 non-null  object
#  2   Global_active_power    102464 non-null  float64
#  3   Global_reactive_power  102464 non-null  float64
#  4   Voltage                102464 non-null  float64
#  5   Global_intensity       102464 non-null  float64
#  6   Sub_metering_1         102464 non-null  int64
#  7   Sub_metering_2         102464 non-null  int64
#  8   Sub_metering_3         102464 non-null  int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 7.0+ MB

# %% [markdown]
# # Estatíscas descridivas (colunas numéricas)
# # Média, mediana, desvio padraão, min, max

# %%
dados.describe()
# Out:
#        Global_active_power  Global_reactive_power        Voltage  \
# count        102464.000000          102464.000000  102464.000000
# mean              1.093568               0.124120     240.831564
# std               1.061280               0.112307       3.241235
# min               0.076000               0.000000     224.920000
# 25%               0.308000               0.048000     238.990000
# 50%               0.602000               0.100000     241.010000
# 75%               1.528000               0.196000     242.880000
# max              10.290000               1.078000     253.750000
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count     102464.000000   102464.000000    102464.00000   102464.000000
# mean           4.635390        1.140976         1.29019        6.504655
# std            4.459188        6.226089         5.80087        8.461418
# min            0.200000        0.000000         0.00000        0.000000
# ...

# %%
# Separação de colunas

dados['Voltage']
# Out:
# 0         240.17
# 1         245.50
# 2         239.85
# 3         235.72
# 4         243.95
#            ...
# 102459    246.67
# 102460    242.90
# 102461    238.47
# 102462    240.21
# 102463    243.38
# Name: Voltage, Length: 102464, dtype: float64

# %% [markdown]
# # Média, mediana e desvio padrão --> populacionais

# %%
dados['Voltage'].mean()
# Out:
# np.float64(240.8315637687383)

# %%
dados['Voltage'].median()
# Out:
# 241.01

# %%
dados['Voltage'].sample(frac=0.05).mean()
# Out:
# np.float64(240.81679094280693)
